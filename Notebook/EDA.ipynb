# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\Admin\\Desktop\\AnamolyDetection\\Notebook\\data\\creditcard_data.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.describe()
# Out:
#                 Time             V1            V2             V3  \
# count  284806.000000  284806.000000  2.848060e+05  284806.000000
# mean    94813.585781       0.000002  6.661837e-07      -0.000002
# std     47488.004530       1.958699  1.651311e+00       1.516257
# min         0.000000     -56.407510 -7.271573e+01     -48.325589
# 25%     54201.250000      -0.920374 -5.985522e-01      -0.890368
# 50%     84691.500000       0.018109  6.549621e-02       0.179846
# 75%    139320.000000       1.315645  8.037257e-01       1.027198
# max    172788.000000       2.454930  2.205773e+01       9.382558
#
#                   V4            V5             V6             V7  \
# count  284806.000000  2.848060e+05  284806.000000  284806.000000
# mean        0.000002  4.405008e-08       0.000002      -0.000006
# std         1.415871  1.380249e+00       1.332273       1.237092
# min        -5.683171 -1.137433e+02     -26.160506     -43.557242
# 25%        -0.848642 -6.915995e-01      -0.768296      -0.554080
# 50%        -0.019845 -5.433621e-02      -0.274186       0.040097
# 75%         0.743348  6.119267e-01       0.398567       0.570426
# max        16.875344  3.480167e+01      73.301626     120.589494
#
#                   V8             V9  ...           V21            V22  \
# count  284806.000000  284806.000000  ...  2.848060e+05  284806.000000
# mean        0.000001      -0.000002  ... -9.166149e-07      -0.000002
# std         1.194355       1.098634  ...  7.345251e-01       0.725702
# min       -73.216718     -13.434066  ... -3.483038e+01     -10.933144
# 25%        -0.208628      -0.643098  ... -2.283974e-01      -0.542351
# 50%         0.022358      -0.051429  ... -2.945020e-02       0.006781
# 75%         0.327346       0.597140  ...  1.863701e-01       0.528548
# max        20.007208      15.594995  ...  2.720284e+01      10.503090
#
#                  V23           V24            V25            V26  \
# count  284806.000000  2.848060e+05  284806.000000  284806.000000
# mean       -0.000001 -3.088756e-08       0.000002       0.000003
# std         0.624461  6.056481e-01       0.521278       0.482225
# min       -44.807735 -2.836627e+00     -10.295397      -2.604551
# 25%        -0.161846 -3.545895e-01      -0.317142      -0.326979
# 50%        -0.011196  4.097671e-02       0.016596      -0.052134
# 75%         0.147641  4.395270e-01       0.350716       0.240955
# max        22.528412  4.584549e+00       7.519589       3.517346
#
#                 V27           V28         Amount          Class
# count  2.848060e+05  2.848060e+05  284806.000000  284806.000000
# mean   8.483873e-09 -4.792707e-08      88.349168       0.001727
# std    4.036332e-01  3.300838e-01     250.120432       0.041527
# min   -2.256568e+01 -1.543008e+01       0.000000       0.000000
# 25%   -7.083961e-02 -5.295995e-02       5.600000       0.000000
# 50%    1.342244e-03  1.124381e-02      22.000000       0.000000
# 75%    9.104579e-02  7.828043e-02      77.160000       0.000000
# max    3.161220e+01  3.384781e+01   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284806 entries, 0 to 284805
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284806 non-null  float64
#  1   V1      284806 non-null  float64
#  2   V2      284806 non-null  float64
#  3   V3      284806 non-null  float64
#  4   V4      284806 non-null  float64
#  5   V5      284806 non-null  float64
#  6   V6      284806 non-null  float64
#  7   V7      284806 non-null  float64
#  8   V8      284806 non-null  float64
#  9   V9      284806 non-null  float64
#  10  V10     284806 non-null  float64
#  11  V11     284806 non-null  float64
#  12  V12     284806 non-null  float64
#  13  V13     284806 non-null  float64
#  14  V14     284806 non-null  float64
#  15  V15     284806 non-null  float64
#  16  V16     284806 non-null  float64
#  17  V17     284806 non-null  float64
#  18  V18     284806 non-null  float64
#  19  V19     284806 non-null  float64
#  20  V20     284806 non-null  float64
#  21  V21     284806 non-null  float64
#  22  V22     284806 non-null  float64
#  23  V23     284806 non-null  float64
#  24  V24     284806 non-null  float64
#  25  V25     284806 non-null  float64
#  26  V26     284806 non-null  float64
#  27  V27     284806 non-null  float64
#  28  V28     284806 non-null  float64
#  29  Amount  284806 non-null  float64
#  30  Class   284806 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
class_counts = df['Class'].value_counts()
print(class_counts)
# Out:
# Class
# 0    284314
# 1       492
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.hist(df['Amount'], bins=30, edgecolor='black')
plt.title('Histogram of Amount')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns

sns.boxplot(df['Amount'])
plt.title('Boxplot of Amount')
plt.xlabel('Amount')
plt.show()

# %%
sns.kdeplot(df['Amount'], shade=True)
plt.title('Density Plot of Amount')
plt.xlabel('Amount')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15220\1929110776.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Amount'], shade=True)

# %%
X = df.drop(columns=['Class'])  
y = df['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284801  172785.0   0.120316   0.931005 -0.546012 -0.745097  1.130314
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284801 -0.235973  0.812722  0.115093 -0.204064  ... -0.314205 -0.808520
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 284801  0.050343  0.102800 -0.435870  0.124079  0.217940  0.068803    2.69
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
#
#         Class
# 284801      0
# 284802      0
# 284803      0
# 284804      0
# 284805      0
#
# [5 rows x 31 columns]

# %%
plt.figure(figsize = (14,14))
plt.title('Credit Card Transactions features correlation plot (Pearson)')
corr = df.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,linewidths=.1,cmap="Reds")
plt.show()

# %%
# !pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: click in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: pandas in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from lazypredict) (2.2.2)
# Collecting tqdm (from lazypredict)
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/57.6 kB ? eta -:--:--
#      --------------------------- ---------- 41.0/57.6 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 57.6/57.6 kB 751.0 kB/s eta 0:00:00
# Requirement already satisfied: joblib in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from lazypredict) (1.4.2)
# Collecting lightgbm (from lazypredict)
#   Downloading lightgbm-4.3.0-py3-none-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: xgboost in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: colorama in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from click->lazypredict) (0.4.6)
# Requirement already satisfied: numpy in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from lightgbm->lazypredict) (1.26.4)
# Requirement already satisfied: scipy in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from lightgbm->lazypredict) (1.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from pandas->lazypredict) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from pandas->lazypredict) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from pandas->lazypredict) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from scikit-learn->lazypredict) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.16.0)
# Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Downloading lightgbm-4.3.0-py3-none-win_amd64.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ----- ---------------------------------- 0.2/1.3 MB 5.1 MB/s eta 0:00:01
#    ------- -------------------------------- 0.2/1.3 MB 3.0 MB/s eta 0:00:01
#    -------- ------------------------------- 0.3/1.3 MB 2.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.4/1.3 MB 2.2 MB/s eta 0:00:01
#    ------------ --------------------------- 0.4/1.3 MB 1.9 MB/s eta 0:00:01
#    -------------- ------------------------- 0.5/1.3 MB 1.8 MB/s eta 0:00:01
#    --------------- ------------------------ 0.5/1.3 MB 1.8 MB/s eta 0:00:01
#    ------------------ --------------------- 0.6/1.3 MB 1.7 MB/s eta 0:00:01
#    ------------------- -------------------- 0.7/1.3 MB 1.6 MB/s eta 0:00:01
#    --------------------- ------------------ 0.7/1.3 MB 1.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.8/1.3 MB 1.6 MB/s eta 0:00:01
#    ------------------------- -------------- 0.8/1.3 MB 1.5 MB/s eta 0:00:01
#    -------------------------- ------------- 0.9/1.3 MB 1.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.3 MB 1.5 MB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.3 MB 1.5 MB/s eta 0:00:01
#    -------------------------------- ------- 1.1/1.3 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.1/1.3 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 1.2/1.3 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 1.3/1.3 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  1.3/1.3 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 1.4 MB/s eta 0:00:00
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ---------------------------------------- 78.3/78.3 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: tqdm, lightgbm, lazypredict
# Successfully installed lazypredict-0.2.12 lightgbm-4.3.0 tqdm-4.66.4

# %%
pip install --upgrade lazypredict
# Out:
# Requirement already satisfied: lazypredict in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (0.2.12)
# Requirement already satisfied: click in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: pandas in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from lazypredict) (2.2.2)
# Requirement already satisfied: tqdm in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from lazypredict) (4.66.4)
# Requirement already satisfied: joblib in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: lightgbm in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from lazypredict) (4.3.0)
# Requirement already satisfied: xgboost in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: colorama in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from click->lazypredict) (0.4.6)
# Requirement already satisfied: numpy in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from lightgbm->lazypredict) (1.26.4)
# Requirement already satisfied: scipy in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from lightgbm->lazypredict) (1.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from pandas->lazypredict) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from pandas->lazypredict) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from pandas->lazypredict) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from scikit-learn->lazypredict) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\desktop\anamolydetection\venv\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
X_train.head()
# Out:
#             Time    V1    V2    V3    V4    V5    V6    V7    V8    V9  ...  \
# 240913 150806.00 -0.25  1.85  0.15  4.22  0.97  1.14  0.30  0.50 -2.18  ...
# 161145 113921.00 -0.13  0.11 -0.65 -1.00  1.81  1.74  0.50  0.63  0.02  ...
# 204520 135319.00  2.13  0.01 -1.51  0.12  0.60 -0.33  0.20 -0.26  0.38  ...
# 182659 125498.00 -0.09  0.17  1.57  0.69  0.22  1.10  1.58 -1.10  0.76  ...
# 25117   33520.00  1.35 -0.53  0.56 -0.63 -1.14 -0.85 -0.64 -0.03 -0.65  ...
#
#          V20   V21   V22   V23   V24   V25   V26   V27   V28  Amount
# 240913  0.31  0.38  1.28 -0.24  0.10 -0.34  0.63  0.36  0.21   10.59
# 161145 -0.06 -0.06  0.01  0.25 -2.47 -0.89  0.34  0.31  0.07   47.89
# 204520 -0.09 -0.33 -0.79  0.27  0.07 -0.14  0.20 -0.07 -0.06    1.98
# 182659  0.05  0.02  1.06 -0.41  0.72 -0.17 -0.61 -1.20 -1.14  170.10
# 25117  -0.07 -0.01 -0.18  0.18  0.35  0.15 -0.40  0.01  0.02    5.96
#
# [5 rows x 30 columns]

# %%
df.head()
# Out:
#    Time    V1    V2   V3    V4    V5    V6    V7    V8    V9  ...   V21   V22  \
# 0  0.00 -1.36 -0.07 2.54  1.38 -0.34  0.46  0.24  0.10  0.36  ... -0.02  0.28
# 1  0.00  1.19  0.27 0.17  0.45  0.06 -0.08 -0.08  0.09 -0.26  ... -0.23 -0.64
# 2  1.00 -1.36 -1.34 1.77  0.38 -0.50  1.80  0.79  0.25 -1.51  ...  0.25  0.77
# 3  1.00 -0.97 -0.19 1.79 -0.86 -0.01  1.25  0.24  0.38 -1.39  ... -0.11  0.01
# 4  2.00 -1.16  0.88 1.55  0.40 -0.41  0.10  0.59 -0.27  0.82  ... -0.01  0.80
#
#     V23   V24   V25   V26   V27   V28  Amount  Class
# 0 -0.11  0.07  0.13 -0.19  0.13 -0.02  149.62      0
# 1  0.10 -0.34  0.17  0.13 -0.01  0.01    2.69      0
# 2  0.91 -0.69 -0.33 -0.14 -0.06 -0.06  378.66      0
# 3 -0.19 -1.18  0.65 -0.22  0.06  0.06  123.50      0
# 4 -0.14  0.14 -0.21  0.50  0.22  0.22   69.99      0
#
# [5 rows x 31 columns]

# %%
from sklearn.metrics import classification_report, roc_auc_score
import xgboost as xgb

# Assuming you already have X (features) and y (target) defined



# Create XGBoost classifier instance
xgb_classifier = xgb.XGBClassifier()

# Fit XGBoost classifier on training data
xgb_classifier.fit(X_train, y_train)

# Make predictions on test data
predictions = xgb_classifier.predict(X_test)

# Compute classification report
report = classification_report(y_test, predictions)

# Compute ROC AUC score
auc_roc_score = roc_auc_score(y_test, predictions)

print("Classification Report:")
print(report)
print("ROC AUC Score:", auc_roc_score)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85294
#            1       0.95      0.78      0.86       148
#
#     accuracy                           1.00     85442
#    macro avg       0.98      0.89      0.93     85442
# weighted avg       1.00      1.00      1.00     85442
#
# ROC AUC Score: 0.8884783410512066

# %%
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split



# Create Gradient Boosting classifier instance
gb_classifier = GradientBoostingClassifier()

# Fit Gradient Boosting classifier on training data
gb_classifier.fit(X_train, y_train)

# Make predictions on test data
predictions = gb_classifier.predict(X_test)

# Compute classification report
report = classification_report(y_test, predictions)

# Compute ROC AUC score
auc_roc_score = roc_auc_score(y_test, predictions)

print("Classification Report:")
print(report)
print("ROC AUC Score:", auc_roc_score)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71081
#            1       0.88      0.82      0.85       121
#
#     accuracy                           1.00     71202
#    macro avg       0.94      0.91      0.92     71202
# weighted avg       1.00      1.00      1.00     71202
#
# ROC AUC Score: 0.9089924298911229

# %%
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split



# Create Logistic Regression classifier instance
logistic_regression = LogisticRegression()

# Fit Logistic Regression classifier on training data
logistic_regression.fit(X_train, y_train)

# Make predictions on test data
predictions = logistic_regression.predict(X_test)

# Compute classification report
report = classification_report(y_test, predictions)

# Compute ROC AUC score
auc_roc_score = roc_auc_score(y_test, predictions)

print("Classification Report:")
print(report)
print("ROC AUC Score:", auc_roc_score)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71081
#            1       0.71      0.68      0.69       121
#
#     accuracy                           1.00     71202
#    macro avg       0.86      0.84      0.85     71202
# weighted avg       1.00      1.00      1.00     71202
#
# ROC AUC Score: 0.8386108456642585
